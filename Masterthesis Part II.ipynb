# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction
#
# ## Comparing Reduction Methods for p = 1.000 & n = 1.000

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from row_column_reduction_study import *
from screening_analysis import *

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/Simulation Data")

# %%
#==============================================================================================
# Simulation Study 1: p = 1.000, n = 1.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(k * np.log(1000))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k50, time_scores_p1000_n1000_k50, C_p1000_n1000_k50, R_p1000_n1000_k50, rmse_p1000_n1000_k50 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  346.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# 1000 1000
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 1.000, n = 1.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# set the reps:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(k * np.log(1000))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k100, time_scores_p1000_n1000_k100, C_p1000_n1000_k100, R_p1000_n1000_k100, rmse_p1000_n1000_k100 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  691.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# 1000 1000
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 1.000, n = 1.000, reps = 10, k = 150, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 150

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k150, time_scores_p1000_n1000_k150, C_p1000_n1000_k150, R_p1000_n1000_k150, rmse_p1000_n1000_k150 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  752.0
# r =  4981.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# (1037, 1000) (1037, 1)
# (1037, 1000) (1037, 1)
# 1037 1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 25
#      22 print("r = ", r)
#      24 # perform the study:
# ---> 25 scores_p1000_n1000_k150, time_scores_p1000_n1000_k150, C_p1000_n1000_k150, R_p1000_n1000_k150, rmse_p1000_n1000_k150 = compare_methods_col_after_row(k, seed, base, folder, reps)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/row_column_reduction_study.py:360, in compare_methods_col_after_row(k, seed, base, folder, reps, gaussian)
#     358 print("Performing data reduction...")
#     359 ## 3. Data Reduction
# --> 360 scores, timing_scores, C, R_reduced, y_reduced = data_reduction(k, df_train, y_train, gaussian)
#     362 print("Visualizing score distributions...")
#     363 ## 4. Score Distributions Visualization
#     364 # visualize_distributions(scores)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/row_column_reduction_study.py:27, in data_reduction(k, df_train, y_train, gaussian)
#      24 y = y.to_numpy().reshape(-1, 1) if isinstance(y, (pd.Series, pd.DataFrame)) else y.reshape(-1, 1)
#      26 # prepare sketched matrix
# ---> 27 R = np.zeros((r,d))
#      29 # created the sketched versions of X and y
#      30 for i in range(n):
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/scoring_functions.py:7, in get_combined_scores(X, y, k, p_leverage)
#       1 import numpy as np
#       2 import pandas as pd
#       4 # ------------------------------------------------------------
#       5 # Function to generate a random score (uniformly distributed) per column
#       6 #
# ----> 7 # INPUT:
#       8 #   X         : design matrix of dimension n x p
#       9 #
#      10 # OUTPUT:
#      11 #   Numeric vector of length p containing random scores between 0 and 1
#      12 # ------------------------------------------------------------
#      13 def get_random_scores(X):
#      14     n_cols = X.shape[1]
#
# ValueError: operands could not be broadcast together with shapes (1000,) (1037,)

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k150, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 1.000, n = 1.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k200, time_scores_p1000_n1000_k200, C_p1000_n1000_k200, R_p1000_n1000_k200, rmse_p1000_n1000_k200 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 5: p = 1.000, n = 1.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k300, time_scores_p1000_n1000_k300, C_p1000_n1000_k300, R_p1000_n1000_k300, rmse_p1000_n1000_k300 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 5: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 10.000 & n = 10.000

# %%
#==============================================================================================
# Simulation Study 1: p = 10.000, n = 10.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k50, time_scores_p10000_n10000_k50, C_p10000_n10000_k50, R_p10000_n10000_k50, rmse_p10000_n10000_k50 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k100, time_scores_p10000_n10000_k100, C_p10000_n10000_k100, R_p10000_n10000_k100, rmse_p10000_n10000_k100 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k200, time_scores_p10000_n10000_k200, C_p10000_n10000_k200, R_p10000_n10000_k200, rmse_p10000_n10000_k200 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 10.000, n = 10.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k300, time_scores_p10000_n10000_k300, C_p10000_n10000_k300, R_p10000_n10000_k300, rmse_p10000_n10000_k300 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 20.000 & n = 20.000
