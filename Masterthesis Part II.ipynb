# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction
#
# ## Comparing Reduction Methods for p = 1.000 & n = 1.000

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from row_column_reduction_study import *
from screening_analysis import *

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/Simulation Data")

# %%
#==============================================================================================
# Simulation Study 1: p = 1.000, n = 1.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(k * np.log(1000))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k50, time_scores_p1000_n1000_k50, C_p1000_n1000_k50, R_p1000_n1000_k50, rmse_p1000_n1000_k50 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  346.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# 346
# (346, 1000)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# (346, 1000) (346, 1)
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 1.000, n = 1.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# set the reps:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(k * np.log(1000))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k100, time_scores_p1000_n1000_k100, C_p1000_n1000_k100, R_p1000_n1000_k100, rmse_p1000_n1000_k100 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  691.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# 691
# (691, 1000)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# (691, 1000) (691, 1)
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 1.000, n = 1.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k200, time_scores_p1000_n1000_k200, C_p1000_n1000_k200, R_p1000_n1000_k200, rmse_p1000_n1000_k200 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 1.000, n = 1.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k300, time_scores_p1000_n1000_k300, C_p1000_n1000_k300, R_p1000_n1000_k300, rmse_p1000_n1000_k300 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 10.000 & n = 10.000

# %%
#==============================================================================================
# Simulation Study 1: p = 10.000, n = 10.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k50, time_scores_p10000_n10000_k50, C_p10000_n10000_k50, R_p10000_n10000_k50, rmse_p10000_n10000_k50 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k100, time_scores_p10000_n10000_k100, C_p10000_n10000_k100, R_p10000_n10000_k100, rmse_p10000_n10000_k100 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 10.000, n = 10.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k200, time_scores_p10000_n10000_k200, C_p10000_n10000_k200, R_p10000_n10000_k200, rmse_p10000_n10000_k200 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 10.000, n = 10.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k300, time_scores_p10000_n10000_k300, C_p10000_n10000_k300, R_p10000_n10000_k300, rmse_p10000_n10000_k300 = compare_methods_col_after_row(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k300, reps)

# %%
#==============================================================================================
# Simulation Study 5: p = 10.000, n = 10.000, reps = 10, k = 400, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 400

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k400, time_scores_p10000_n10000_k400, C_p10000_n10000_k400, R_p10000_n10000_k400, rmse_p10000_n10000_k400 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 5: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k400, reps)

# %%
#==============================================================================================
# Simulation Study 6: p = 10.000, n = 10.000, reps = 10, k = 500, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 500

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k500, time_scores_p10000_n10000_k500, C_p10000_n10000_k500, R_p10000_n10000_k500, rmse_p10000_n10000_k500 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 6: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k500, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 20.000 & n = 20.000

# %%
#==============================================================================================
# Simulation Study 1: p = 20.000, n = 20.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k50, time_scores_p20000_n20000_k50, C_p20000_n20000_k50, R_p20000_n20000_k50, rmse_p20000_n20000_k50 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 20.000, n = 20.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k100, time_scores_p20000_n20000_k100, C_p20000_n20000_k100, R_p20000_n20000_k100, rmse_p20000_n20000_k100 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 20.000, n = 20.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k200, time_scores_p20000_n20000_k200, C_p20000_n20000_k200, R_p20000_n20000_k200, rmse_p20000_n20000_k200 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 20.000, n = 20.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k300, time_scores_p20000_n20000_k300, C_p20000_n20000_k300, R_p20000_n20000_k300, rmse_p20000_n20000_k300 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k300, reps)

# %%
#==============================================================================================
# Simulation Study 5: p = 20.000, n = 20.000, reps = 10, k = 400, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 400

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k400, time_scores_p20000_n20000_k400, C_p20000_n20000_k400, R_p20000_n20000_k400, rmse_p20000_n20000_k400 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 5: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k400, reps)

# %%
#==============================================================================================
# Simulation Study 6: p = 20.000, n = 20.000, reps = 10, k = 500, seed = 1
#==============================================================================================

# set the folder:
folder = "p20000_n20000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 500

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p20000_n20000_k500, time_scores_p20000_n20000_k500, C_p20000_n20000_k500, R_p20000_n20000_k500, rmse_p20000_n20000_k500 = compare_methods_col_after_row(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 6: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p20000_n20000_k500, reps)
