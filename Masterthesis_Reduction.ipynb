# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction - Reduction

# %% [markdown]
# ## 1. Setup of Notebook

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from column_row_reduction_study import *
from row_column_reduction_study import *
from column_row_reduction_study_log_reg import *
from row_column_reduction_study_lasso import *
from visualizations import *
import pickle

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis")

# %%
#==============================================================================================
# Setting if study should be performed or the results should be loaded from storage
#==============================================================================================
def save_results(filename, **kwargs):
    with open(filename, "wb") as f:
        pickle.dump(kwargs, f)

def load_results(filename):
    with open(filename, "rb") as f:
        return pickle.load(f)

# %%
#==============================================================================================
# General Settings
#==============================================================================================

# setting the k values
k_vector = [10,20,25,50,100,200,300,400,500]

# set the seed
seed = 1

# setting the reps
reps = 10

# %% [markdown]
# ## 2. Row Reduction After Column Reduction Analysis

# %% [markdown]
# ### 2.1. p = 1.000 and n = 1.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 1,000, n = 1,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p1000_n1000"

# specify the results folder
results_folder = "Results/column_row/p1000_n1000"

# container for all results across k
results_1000_cr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results for this k
    results_1000_cr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p1000_n1000_k{k}.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Running outer repetition with seed = 1
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 2
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 3
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# ...

# %% [markdown]
# ### 2.2. p = 5.000 and n = 5.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 5,000, n = 5,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p5000_n5000"

# specify the results folder
results_folder = "Results/column_row/p5000_n5000"

# container for all results across k
results_5000_cr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results for this k
    results_5000_cr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p5000_n5000_k{k}.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 20
# ------------------------------------------------------------
# Running simulation for k = 25
# ...

# %% [markdown]
# ### 2.3. p = 10.000 and n = 10.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 10,000, n = 10,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p10000_n10000"

# specify the results folder
results_folder = "Results/column_row/p10000_n10000"

# container for all results across k
results_10000_cr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results for this k
    results_10000_cr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p10000_n10000_k{k}.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 20
# ------------------------------------------------------------
# Running simulation for k = 25
# ...

# %% [markdown]
# ## 3. Column Reduction without Row Reduction Analysis

# %% [markdown]
# ### 3.1. p = 1.000 and n = 1.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 1,000, n = 1,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p1000_n1000"

# specify the results folder
results_folder = "Results/column_row/p1000_n1000rr"

# container for all results across k
results_1000_cr_rr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10,
        row_reduction=False
    )

    # store results for this k
    results_1000_cr_rr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p1000_n1000_k{k}rr.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Running outer repetition with seed = 1
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 2
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 3
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# ...

# %% [markdown]
# ### 3.2. p = 5.000 and n = 5.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 5,000, n = 5,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p5000_n5000"

# specify the results folder
results_folder = "Results/column_row/p5000_n5000rr"

# container for all results across k
results_5000_cr_rr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10,
        row_reduction=False
    )

    # store results for this k
    results_5000_cr_rr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p5000_n5000_k{k}rr.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 20
# ------------------------------------------------------------
# Running simulation for k = 25
# ...

# %% [markdown]
# ### 3.3. p = 10.000 and n = 10.000

# %%
# ------------------------------------------------------------
# Simulation Study: p = 10,000, n = 10,000, reps = 10
# ------------------------------------------------------------

# specify the simulation data folder
data_folder = "Simulation Data2/p10000_n10000"

# specify the results folder
results_folder = "Results/column_row/p10000_n10000rr"

# container for all results across k
results_10000_cr_rr = {}

for k in k_vector:

    # progress information
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run extended sampling variance analysis
    # this internally runs the full wrapper outer_reps times
    results = run_sampling_variance_row_after_col(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10,
        row_reduction=False
    )

    # store results for this k
    results_10000_cr_rr[k] = results

    # save results to file
    save_results(
    f"{base}/{results_folder}/results_cr_p10000_n10000_k{k}rr.pkl",
        results=results
    )


    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 20
# ------------------------------------------------------------
# Running simulation for k = 25
# ...

# %% [markdown]
# ## 4. Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 4.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1,000, n = 1,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p1000_n1000"

# specify the results folder
results_folder = "Results/row_column/p1000_n1000"

# container for all results across k
results_1000_rc = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run full CUR-based reduction + modeling
    result = run_sampling_variance_col_after_row(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_1000_rc[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_rc_p1000_n1000_k{k}.pkl",
        results=result
    )

    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Running outer repetition with seed = 1
# Reading simulation data...
# Performing data reduction...
# Fitting linear models...
# Computing full model benchmark...
# Completed.
# Running outer repetition with seed = 2
# Reading simulation data...
# Performing data reduction...
# Fitting linear models...
# Computing full model benchmark...
# Completed.
# Running outer repetition with seed = 3
# Reading simulation data...
# Performing data reduction...
# Fitting linear models...
# Computing full model benchmark...
# Completed.
# Running outer repetition with seed = 4
# Reading simulation data...
# Performing data reduction...
# Fitting linear models...
# Computing full model benchmark...
# Completed.
# Running outer repetition with seed = 5
# Reading simulation data...
# Performing data reduction...
# Fitting linear models...
# ...

# %% [markdown]
# ### 4.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5,000, n = 5,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p5000_n5000"

# specify the results folder
results_folder = "Results/row_column/p5000_n5000"

# container for all results across k
results_5000_rc = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run full CUR-based reduction + modeling
    result = run_sampling_variance_col_after_row(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_5000_rc[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_rc_p5000_n5000_k{k}.pkl",
        **result
    )

    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 20
#      17 print("------------------------------------------------------------")
# ...

# %% [markdown]
# ### 4.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10,000, n = 10,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p10000_n10000"

# specify the results folder
results_folder = "Results/row_column/p10000_n10000"

# container for all results across k
results_10000_rc = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run full CUR-based reduction + modeling
    result = run_sampling_variance_col_after_row(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_10000_rc[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_rc_p10000_n10000_k{k}.pkl",
        **result
    )

    print(f"Saved results for k = {k}")

# %% [markdown]
# ## 5. Logistic Regression: Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 5.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1,000, n = 1,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p1000_n1000"

# specify the results folder
results_folder = "Results/log_reg/p1000_n1000"

# container for all results across k
results_1000_log_reg_cr = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run logistic CUR-based reduction + modeling
    result = run_sampling_variance_row_after_col_log(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_1000_log_reg_cr[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p1000_n1000_k{k}.pkl",
        results=result
    )

    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Running outer repetition with seed = 1
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 2
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 3
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# Running outer repetition with seed = 4
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# ...

# %% [markdown]
# ### 5.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5,000, n = 5,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p5000_n5000"

# specify the results folder
results_folder = "Results/log_reg/p5000_n5000"

# container for all results across k
results_5000_log_reg_cr = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run logistic CUR-based reduction + modeling
    result = run_sampling_variance_row_after_col_log(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_5000_log_reg_cr[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p5000_n5000_k{k}.pkl",
        results=result
    )

    print(f"Saved results for k = {k}")

# %% [markdown]
# ### 5.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10,000, n = 10,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p10000_n10000"

# specify the results folder
results_folder = "Results/log_reg/p10000_n10000"

# container for all results across k
results_10000_log_reg_cr = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running simulation for k = {k}")
    print("------------------------------------------------------------")

    # run logistic CUR-based reduction + modeling
    result = run_sampling_variance_row_after_col_log(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results in dictionary
    results_10000_log_reg_cr[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p10000_n10000_k{k}.pkl",
        results=result
    )

    print(f"Saved results for k = {k}")

# %% [markdown]
# ## 6. LASSO Analysis

# %% [markdown]
# ### 6.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1,000, n = 1,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p1000_n1000"

# specify the results folder
results_folder = "Results/lasso/p1000_n1000"

# container for all results across k
results_1000_lasso = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running Lasso simulation for k = {k}")
    print("------------------------------------------------------------")

    # run row-reduction + lasso modeling
    result = run_sampling_variance_lasso_after_row_reduction(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results directly (dictionary)
    results_1000_lasso[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_lasso_p1000_n1000_k{k}.pkl",
        results=result
    )

    print(f"Saved results for k = {k}")
# Out:
# ------------------------------------------------------------
# Running Lasso simulation for k = 10
# ------------------------------------------------------------
# Running outer repetition with seed = 1
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# Completed.
# Running outer repetition with seed = 2
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# Completed.
# Running outer repetition with seed = 3
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# Completed.
# Running outer repetition with seed = 4
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# Completed.
# Running outer repetition with seed = 5
# Reading in the simulation data...
# Setting the seed...
# ...

# %% [markdown]
# ### 6.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5,000, n = 5,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p5000_n5000"

# specify the results folder
results_folder = "Results/lasso/p5000_n5000"

# container for all results across k
results_5000_lasso = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running Lasso simulation for k = {k}")
    print("------------------------------------------------------------")

    # run row-reduction + lasso modeling
    result = run_sampling_variance_lasso_after_row_reduction(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results directly (dictionary)
    results_5000_lasso[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_lasso_p5000_n5000_k{k}.pkl",
        **result
    )

    print(f"Saved results for k = {k}")

# %% [markdown]
# ### 6.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10,000, n = 10,000, reps = 10
#==============================================================================================

# specify the simulation data folder
data_folder = "Simulation Data2/p10000_n10000"

# specify the results folder
results_folder = "Results/lasso/p10000_n10000"

# container for all results across k
results_10000_lasso = {}

for k in k_vector:
    print("------------------------------------------------------------")
    print(f"Running Lasso simulation for k = {k}")
    print("------------------------------------------------------------")

    # run row-reduction + lasso modeling
    result = run_sampling_variance_lasso_after_row_reduction(
        k=k,
        base=base,
        folder=data_folder,
        reps=10,
        outer_reps=10
    )

    # store results directly (dictionary)
    results_10000_lasso[k] = result

    # save results to file
    save_results(
        f"{base}/{results_folder}/results_lasso_p10000_n10000_k{k}.pkl",
        **result
    )

    print(f"Saved results for k = {k}")

# %% [markdown]
# ### 6.4 Alpha Analysis

# %%
def plot_alpha_vs_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        for rep, a in enumerate(alphas):
            rows.append({"k": k, "Replication": rep+1, "alpha": a})

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k", y="alpha"))
        + geom_boxplot(fill="#4C72B0")
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: α vs. k",
            x="k",
            y="α (Regularization Strength)"
        )
    )

    display(p)
    return df, p


def plot_alpha_distribution(results_lasso, k):
    alphas = results_lasso[k]["alphas"]["Binary"]

    df = pd.DataFrame({"alpha": alphas, "Replication": np.arange(1, len(alphas)+1)})

    p = (
        ggplot(df, aes(x="alpha"))
        + geom_histogram(bins=10, fill="#55A868", color="black")
        + theme_minimal()
        + labs(
            title=f"Distribution of α for k = {k}",
            x="α",
            y="Count"
        )
    )

    display(p)
    return df, p


def compare_alpha_to_theoretical(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        alpha_theory = 1 / np.sqrt(k * np.log(k))

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep+1,
                "alpha_binary": a,
                "alpha_theory": alpha_theory
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k"))
        + geom_boxplot(aes(y="alpha_binary"), fill="#4C72B0")
        + geom_boxplot(aes(y="alpha_theory"), fill="#DD8452", alpha=0.5)
        + theme_minimal()
        + labs(
            title="Binary-Search α vs. Theoretical α",
            x="k",
            y="α"
        )
    )

    display(p)
    return df, p


def plot_lambda_vs_inverse_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        inv_k = 1 / k

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep + 1,
                "alpha": a,
                "inv_k": inv_k
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="inv_k", y="alpha"))
        + geom_boxplot(aes(group="k", fill="k"), alpha=0.7)
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: λ (alpha) vs. 1/k",
            x="1 / k",
            y="λ (Regularization Strength)"
        )
    )

    display(p)
    return df, p

# %%
plot_alpha_vs_k(results_1000_lasso, k_vector)

# %%
plot_alpha_distribution(results_1000_lasso, 25)

# %%
compare_alpha_to_theoretical(results_1000_lasso, k_vector)

# %%
plot_lambda_vs_inverse_k(results_1000_lasso, k_vector)
