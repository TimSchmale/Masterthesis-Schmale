# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction - Reduction

# %% [markdown]
# ## 1. Setup of Notebook

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from column_row_reduction_study import *
from row_column_reduction_study import *
from column_row_reduction_study_log_reg import apply_row_after_col_reduction_log
from row_column_reduction_study_lasso import apply_lasso_after_row_reduction
from screening_analysis import *
from visualizations import *
import pickle

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis")

# %%
#==============================================================================================
# Setting if study should be performed or the results should be loaded from storage
#==============================================================================================
run = True

def save_results(filename, **kwargs):
    with open(filename, "wb") as f:
        pickle.dump(kwargs, f)

def load_results(filename):
    with open(filename, "rb") as f:
        return pickle.load(f)

# %%
#==============================================================================================
# General Settings
#==============================================================================================

# setting the k values
k_vector = [10,20,25,50,100,200,300,400,500]

# set the seed
seed = 1

# setting the reps
reps = 10

# %% [markdown]
# ## 2. Row Reduction After Column Reduction Analysis

# %% [markdown]
# ### 2.1. p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1.000, n = 1.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p1000_n1000"

results_folder = "Results/column_row/p1000_n1000"

# Calculating the Results
results_1000_cr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_1000_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p1000_n1000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 2.2. p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5.000, n = 5.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p5000_n5000"

results_folder = "Results/column_row/p5000_n5000"

# Calculating the Results
results_5000_cr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_5000_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p5000_n5000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 2.3. p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10.000, n = 10.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p10000_n10000"

results_folder = "Results/column_row/p10000_n10000"

# Calculating the Results
results_10000_cr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_10000_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p10000_n10000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...

# %% [markdown]
# ## 3. Column Reduction without Row Reduction Analysis

# %% [markdown]
# ### 3.1. p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1.000, n = 1.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p1000_n1000"

results_folder = "Results/column_row/p1000_n1000rr"

# Calculating the Results
results_1000_cr_rr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_1000_cr_rr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p1000_n1000_k{k}rr.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 3.2. p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5.000, n = 5.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p5000_n5000"

results_folder = "Results/column_row/p5000_n5000rr"

# Calculating the Results
results_5000_cr_rr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_5000_cr_rr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p5000_n5000_k{k}rr.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      22 for k in k_vector:
#      23     print("k = ", k)
# ---> 24     scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
#      25         k, seed, base, data_folder, reps
#      26     )
#      28     results_5000_cr_rr[k] = {
#      29         "Scores": scores,
#      30         "Time": time_scores,
#    (...)     33         "RMSE": rmse
#      34     }
#      36     # save results
#
# NameError: name 'apply_row_after_col_reduction' is not defined

# %% [markdown]
# ### 3.3. p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10.000, n = 10.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p10000_n10000"

results_folder = "Results/column_row/p10000_n10000rr"

# Calculating the Results
results_10000_cr_rr = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_row_after_col_reduction(
        k, seed, base, data_folder, reps
    )

    results_10000_cr_rr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_cr_p10000_n10000_k{k}rr.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...

# %% [markdown]
# ## 4. Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 4.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1.000, n = 1.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p1000_n1000"

results_folder = "Results/row_column/p1000_n1000"

# Calculating the Results
results_1000_rc = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_col_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_1000_rc[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_rc_p1000_n1000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse  
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 4.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5.000, n = 5.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p5000_n5000"

results_folder = "Results/row_column/p5000_n5000"

# Calculating the Results
results_5000_rc = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_col_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_5000_rc[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_rc_p5000_n5000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse  
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 4.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10.000, n = 10.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p10000_n10000"

results_folder = "Results/row_column/p10000_n10000"

# Calculating the Results
results_10000_rc = {}

for k in k_vector:
    print("k = ", k)
    scores, time_scores, C, R, rmse = apply_col_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_10000_rc[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "RMSE": rmse
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_rc_p10000_n10000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        RMSE=rmse
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building linear models...
# Running Lasso (Shrinkage baseline)...

# %% [markdown]
# ## 5. Logistic Regression: Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 5.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1.000, n = 1.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p1000_n1000"

results_folder = "Results/log_reg/p1000_n1000"

# Calculating the Results
results_1000_log_reg_cr = {}

for k in k_vector:
    print("k = ", k)

    scores, time_scores, C, R, brierloss, mu = apply_row_after_col_reduction_log(
        k, seed, base, data_folder, reps
    )

    results_1000_log_reg_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "brierloss": brierloss,
        "mu": mu
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p1000_n1000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        brierloss=brierloss,
        mu=mu
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.

# %% [markdown]
# ### 5.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5.000, n = 5.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p5000_n5000"

results_folder = "Results/log_reg/p5000_n5000"

# Calculating the Results
results_5000_log_reg_cr = {}

for k in k_vector:
    print("k = ", k)

    scores, time_scores, C, R, brierloss, mu = apply_row_after_col_reduction_log(
        k, seed, base, data_folder, reps
    )

    results_5000_log_reg_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "brierloss": brierloss,
        "mu": mu
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p5000_n5000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        brierloss=brierloss,
        mu=mu
    )

# %% [markdown]
# ### 5.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10.000, n = 10.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p10000_n10000"

results_folder = "Results/log_reg/p10000_n10000"

# Calculating the Results
results_10000_log_reg_cr = {}

for k in k_vector:
    print("k = ", k)

    scores, time_scores, C, R, brierloss, mu = apply_row_after_col_reduction_log(
        k, seed, base, data_folder, reps
    )

    results_10000_log_reg_cr[k] = {
        "Scores": scores,
        "Time": time_scores,
        "C": C,
        "R": R,
        "brierloss": brierloss,
        "mu": mu
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_log_reg_cr_p10000_n10000_k{k}.pkl",
        Scores=scores,
        Time=time_scores,
        C=C,
        R=R,
        brierloss=brierloss,
        mu=mu
    )

# %% [markdown]
# ## 6. LASSO Analysis

# %% [markdown]
# ### 6.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: p = 1.000, n = 1.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p1000_n1000"

results_folder = "Results/lasso/p1000_n1000"

# Calculating the Results
results_1000_lasso = {}

for k in k_vector:
    print("k = ", k)

    R_reduced, rmse, betas, feature_counts, alphas = apply_lasso_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_1000_lasso[k] = {
        "R": R_reduced,
        "RMSE": rmse,
        "betas": betas,
        "feature_counts": feature_counts,
        "alphas": alphas
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_lasso_p1000_n1000_k{k}.pkl",
        R=R_reduced,
        rmse=rmse,
        betas=betas,
        feature_counts=feature_counts,
        alphas=alphas
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...

# %% [markdown]
# ### 6.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: p = 5.000, n = 5.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p5000_n5000"

results_folder = "Results/lasso/p5000_n5000"

# Calculating the Results
results_5000_lasso = {}

for k in k_vector:
    print("k = ", k)

    R_reduced, rmse, betas, feature_counts, alphas = apply_lasso_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_5000_lasso[k] = {
        "R": R_reduced,
        "RMSE": rmse,
        "betas": betas,
        "feature_counts": feature_counts,
        "alphas": alphas
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_lasso_p5000_n5000_k{k}.pkl",
        R=R_reduced,
        rmse=rmse,
        betas=betas,
        feature_counts=feature_counts,
        alphas=alphas
    )
# Out:
# k =  10
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  20
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  25
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  50
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  100
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  200
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  300
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  400
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...
# k =  500
# Reading in the simulation data...
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary)...

# %% [markdown]
# ### 6.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: p = 10.000, n = 10.000, reps = 10
#==============================================================================================

# setting the specific folder:
data_folder = "Simulation Data2/p10000_n10000"

results_folder = "Results/lasso/p10000_n10000"

# Calculating the Results
results_10000_lasso = {}

for k in k_vector:
    print("k = ", k)

    R_reduced, rmse, betas, feature_counts, alphas = apply_lasso_after_row_reduction(
        k, seed, base, data_folder, reps
    )

    results_10000_lasso[k] = {
        "R": R_reduced,
        "RMSE": rmse,
        "betas": betas,
        "feature_counts": feature_counts,
        "alphas": alphas
    }

    # save results
    save_results(
        f"{base}/{results_folder}/results_lasso_p10000_n10000_k{k}.pkl",
        R=R_reduced,
        rmse=rmse,
        betas=betas,
        feature_counts=feature_counts,
        alphas=alphas
    )
# Out:
# Loading Data from Storage...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 52
#      49 results_5000_lasso = {}
#      51 for k in k_vector:
# ---> 52     loaded = load_results(
#      53         f"{base}/{results_folder}/results_lasso_p5000_n5000_k{k}.pkl"
#      54     )
#      56     results_5000_lasso[k] = {
#      57         "R": loaded["R"],
#      58         "RMSE": loaded["rmse"],
#      59         "betas": loaded["betas"],
#      60         "feature_counts": loaded["feature_counts"]
#      61     }
#      63 print("Data load completed.")
#
# Cell In[46], line 11, in load_results(filename)
#      10 def load_results(filename):
# ---> 11     with open(filename, "rb") as f:
#      12         return pickle.load(f)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/Results/lasso/p5000_n5000/results_lasso_p5000_n5000_k10.pkl'

# %% [markdown]
# ### 6.4 Alpha Analysis

# %%
def plot_alpha_vs_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        for rep, a in enumerate(alphas):
            rows.append({"k": k, "Replication": rep+1, "alpha": a})

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k", y="alpha"))
        + geom_boxplot(fill="#4C72B0")
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: α vs. k",
            x="k",
            y="α (Regularization Strength)"
        )
    )

    display(p)
    return df, p


def plot_alpha_distribution(results_lasso, k):
    alphas = results_lasso[k]["alphas"]["Binary"]

    df = pd.DataFrame({"alpha": alphas, "Replication": np.arange(1, len(alphas)+1)})

    p = (
        ggplot(df, aes(x="alpha"))
        + geom_histogram(bins=10, fill="#55A868", color="black")
        + theme_minimal()
        + labs(
            title=f"Distribution of α for k = {k}",
            x="α",
            y="Count"
        )
    )

    display(p)
    return df, p


def compare_alpha_to_theoretical(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        alpha_theory = 1 / np.sqrt(k * np.log(k))

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep+1,
                "alpha_binary": a,
                "alpha_theory": alpha_theory
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k"))
        + geom_boxplot(aes(y="alpha_binary"), fill="#4C72B0")
        + geom_boxplot(aes(y="alpha_theory"), fill="#DD8452", alpha=0.5)
        + theme_minimal()
        + labs(
            title="Binary-Search α vs. Theoretical α",
            x="k",
            y="α"
        )
    )

    display(p)
    return df, p


def plot_lambda_vs_inverse_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        inv_k = 1 / k

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep + 1,
                "alpha": a,
                "inv_k": inv_k
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="inv_k", y="alpha"))
        + geom_boxplot(aes(group="k", fill="k"), alpha=0.7)
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: λ (alpha) vs. 1/k",
            x="1 / k",
            y="λ (Regularization Strength)"
        )
    )

    display(p)
    return df, p

# %%
plot_alpha_vs_k(results_1000_lasso, k_vector)
# Out:
# (      k  Replication      alpha
#  0    10            1  17.154379
#  1    10            2  11.652155
#  2    10            3  11.863662
#  3    10            4  14.855080
#  4    10            5  17.270491
#  ..  ...          ...        ...
#  85  500            6   0.100904
#  86  500            7   0.113419
#  87  500            8   0.111397
#  88  500            9   0.090580
#  89  500           10   0.122775
#
#  [90 rows x 3 columns],
#  <plotnine.ggplot.ggplot object at 0x1284f5d60>)

# %%
plot_alpha_distribution(results_1000_lasso, 25)
# Out:
# (      alpha  Replication
#  0  6.978306            1
#  1  5.725488            2
#  2  4.697589            3
#  3  6.152654            4
#  4  4.761397            5
#  5  5.048066            6
#  6  5.280271            7
#  7  5.623413            8
#  8  4.216965            9
#  9  5.424691           10,
#  <plotnine.ggplot.ggplot object at 0x11d6886e0>)

# %%
compare_alpha_to_theoretical(results_1000_lasso, k_vector)
# Out:
# (      k  Replication  alpha_binary  alpha_theory
#  0    10            1     17.154379      0.208397
#  1    10            2     11.652155      0.208397
#  2    10            3     11.863662      0.208397
#  3    10            4     14.855080      0.208397
#  4    10            5     17.270491      0.208397
#  ..  ...          ...           ...           ...
#  85  500            6      0.100904      0.017939
#  86  500            7      0.113419      0.017939
#  87  500            8      0.111397      0.017939
#  88  500            9      0.090580      0.017939
#  89  500           10      0.122775      0.017939
#
#  [90 rows x 4 columns],
#  <plotnine.ggplot.ggplot object at 0x128241e20>)

# %%
plot_lambda_vs_inverse_k(results_1000_lasso, k_vector)
# Out:
# (      k  Replication      alpha  inv_k
#  0    10            1  17.154379  0.100
#  1    10            2  11.652155  0.100
#  2    10            3  11.863662  0.100
#  3    10            4  14.855080  0.100
#  4    10            5  17.270491  0.100
#  ..  ...          ...        ...    ...
#  85  500            6   0.100904  0.002
#  86  500            7   0.113419  0.002
#  87  500            8   0.111397  0.002
#  88  500            9   0.090580  0.002
#  89  500           10   0.122775  0.002
#
#  [90 rows x 4 columns],
#  <plotnine.ggplot.ggplot object at 0x11d59c9b0>)
