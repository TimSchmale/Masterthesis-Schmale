# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction - Reduction

# %% [markdown]
# ## 1. Setup of Notebook

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from column_row_reduction_study import *
from row_column_reduction_study import *
from column_row_reduction_study_log_reg import *
from row_column_reduction_study_lasso import *
from visualizations import *
import pickle

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis")

# %%
#==============================================================================================
# Setting if study should be performed or the results should be loaded from storage
#==============================================================================================
def save_results(filename, **kwargs):
    with open(filename, "wb") as f:
        pickle.dump(kwargs, f)

# %%
#==============================================================================================
# General Settings
#==============================================================================================

# setting the k values
k_vector = [10,20,25,50,100,200,300,400,500]

# set the seed
seed = 1

# setting the reps
reps = 10

# %% [markdown]
# ## 2. Row Reduction After Column Reduction Analysis

# %% [markdown]
# ### 2.1. p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: Row-after-Column CUR (p = 1000, n = 1000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p1000_n1000"
results_folder = "Results/column_row/p1000_n1000"

print("Running Row-after-Column CUR sampling-variance study...")

results_1000_cr = run_sampling_variance_row_after_col(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    row_reduction=True,
    results_folder = results_folder,
    save_name="results_cr_p1000_n1000"
)

save_results(
    f"{base}/{results_folder}/results_cr_p1000_n1000.pkl",
    results=results_1000_cr
)

print("Saved Row-after-Column CUR results.")
# Out:
# Running Row-after-Column CUR sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 10
#       6 results_folder = "Results/column_row/p1000_n1000"
#       8 print("Running Row-after-Column CUR sampling-variance study...")
# ---> 10 results_1000_cr = run_sampling_variance_row_after_col(
#      11     k_vector=k_vector,
#      12     base=base,
#      13     folder=data_folder,
#      14     reps=10,
#      15     outer_reps=10,
#      16     test_size=0.2,
#      17     row_reduction=True,
#      18     results_folder = results_folder,
#      19     save_name="results_cr_p1000_n1000"
#      20 )
#      22 save_results(
# ...

# %% [markdown]
# ### 2.2. p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: Row-after-Column CUR (p = 5000, n = 5000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p5000_n5000"
results_folder = "Results/column_row/p5000_n5000"

print("Running Row-after-Column CUR sampling-variance study...")

results_5000_cr = run_sampling_variance_row_after_col(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    row_reduction=True,
    save_name="results_cr_p5000_n5000",
    results_folder = results_folder
)

save_results(
    f"{base}/{results_folder}/results_cr_p5000_n5000.pkl",
    results=results_5000_cr
)

print("Saved Row-after-Column CUR results.")
# Out:
# Running Row-after-Column CUR sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# ...

# %% [markdown]
# ### 2.3. p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: Row-after-Column CUR (p = 10000, n = 10000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p10000_n10000"
results_folder = "Results/column_row/p10000_n10000"

print("Running Row-after-Column CUR sampling-variance study...")

results_10000_cr = run_sampling_variance_row_after_col(
    k_vector=k_vector,
    base=base,
    folder=data_folder,
    reps=10,
    outer_reps=10,
    test_size=0.2,
    row_reduction=True,
    save_name="results_cr_p10000_n10000",
    results_folder = results_folder,
    seed_from=2,
    seed_to=10
)


save_results(
    f"{base}/{results_folder}/results_cr_p10000_n10000.pkl",
    results=results_10000_cr
)

print("Saved Row-after-Column CUR results.")
# Out:
# Running Row-after-Column CUR sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 2
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline (seed = 2)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline (seed = 2)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# ...

# %% [markdown]
# ## 3. Column Reduction without Row Reduction Analysis

# %% [markdown]
# ### 3.1. p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: Column only (p = 1000, n = 1000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p1000_n1000"
results_folder = "Results/column_only/p1000_n1000"

print("Running Column only CUR sampling-variance study...")

results_1000_no_rr = run_sampling_variance_row_after_col(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    row_reduction=False,
    results_folder = results_folder,
    save_name="results_no_rr_p1000_n1000"
)

save_results(
    f"{base}/{results_folder}/results_no_rr_p1000_n1000.pkl",
    results=results_1000_no_rr
)

print("Saved Column only CUR results.")
# Out:
# Running Column only CUR sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# ...

# %% [markdown]
# ### 3.2. p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: Column only (p = 5000, n = 5000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p5000_n5000"
results_folder = "Results/column_only/p5000_n5000"

print("Running Column only CUR sampling-variance study...")

results_5000_no_rr = run_sampling_variance_row_after_col(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    row_reduction=False,
    results_folder = results_folder,
    save_name="results_no_rr_p5000_n5000"
)

save_results(
    f"{base}/{results_folder}/results_no_rr_p5000_n5000.pkl",
    results=results_5000_no_rr
)

print("Saved Column only CUR results.")
# Out:
# Running Column only CUR sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline (seed = 1)...
# Performing data reduction (column + optional row reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (RMSE)...
# ...

# %% [markdown]
# ### 3.3. p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: Column only (p = 10000, n = 10000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p10000_n10000"
results_folder = "Results/column_only/p10000_n10000"

print("Running Column only CUR sampling-variance study...")

results_10000_no_rr = run_sampling_variance_row_after_col(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    row_reduction=False,
    results_folder = results_folder,
    save_name="results_no_rr_p10000_n10000"
)

save_results(
    f"{base}/{results_folder}/results_no_rr_p10000_n10000.pkl",
    results=results_10000_no_rr
)

print("Saved Column only CUR results.")
# Out:
# ------------------------------------------------------------
# Running simulation for k = 10
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 10
# ------------------------------------------------------------
# Running simulation for k = 20
# ------------------------------------------------------------
# Reading simulation data for 10 replications...
# Setting random seed...
# Performing data reduction (scores + column reduction)...
# Fitting linear models on reduced data...
# Computing full-model benchmark (oracle RMSE)...
# Data Reduction & Modeling completed.
# Saved results for k = 20
# ------------------------------------------------------------
# Running simulation for k = 25
# ...

# %% [markdown]
# ## 4. Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 4.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 1000, n = 1000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p1000_n1000"
results_folder = "Results/row_column/p1000_n1000"

print("Running Row-Column Reduction sampling-variance study...")

results_1000_rc = run_sampling_variance_col_after_row(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_rc_p1000_n1000"
)

save_results(
    f"{base}/{results_folder}/results_rc_p1000_n1000.pkl",
    results=results_1000_rc
)

print("Saved Row-Column results.")
# Out:
# Running Row-Column Reduction sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# --- Running k = 10 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 25 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 50 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# ...

# %% [markdown]
# ### 4.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 5000, n = 5000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p5000_n5000"
results_folder = "Results/row_column/p5000_n5000"

print("Running Row-Column Reduction sampling-variance study...")

results_5000_rc = run_sampling_variance_col_after_row(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_rc_p5000_n5000"
)

save_results(
    f"{base}/{results_folder}/results_rc_p5000_n5000.pkl",
    results=results_5000_rc
)

print("Saved Row-Column results.")
# Out:
# Running Row-Column Reduction sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# --- Running k = 10 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 25 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# Fitting linear models on reduced data...
# Computing full model benchmark (RMSE)...
# Data Reduction & Modeling completed.
#
# --- Running k = 50 ---
# Setting random seed inside hybrid reduction pipeline (seed = 1)...
# Performing data reduction...
# ...

# %% [markdown]
# ### 4.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 10000, n = 10000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p10000_n10000"
results_folder = "Results/row_column/p10000_n10000"

print("Running Row-Column Reduction sampling-variance study...")

results_10000_rc = run_sampling_variance_col_after_row(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_rc_p10000_n10000"
)

save_results(
    f"{base}/{results_folder}/results_rc_p10000_n10000.pkl",
    results=results_10000_rc
)

print("Saved Row-Column results.")

# %% [markdown]
# ## 5. Logistic Regression: Column Reduction After Row Reduction Analysis

# %% [markdown]
# ### 5.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 1000, n = 1000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p1000_n1000"
results_folder = "Results/log_reg/p1000_n1000"

print("Running Row-Column Reduction sampling-variance study...")

results_1000_log_reg_cr = run_sampling_variance_row_after_col_log(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_log_reg_cr_p1000_n1000"
)

save_results(
    f"{base}/{results_folder}/results_log_reg_cr_p1000_n1000.pkl",
    results=results_1000_log_reg_cr
)

print("Saved Logistic Regression results.")
# Out:
# Running Row-Column Reduction sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline for log. regression (seed = 1)...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline for log. regression (seed = 1)...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
#
# --- Running k = 25 ---
# ...

# %% [markdown]
# ### 5.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 5000, n = 5000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p5000_n5000"
results_folder = "Results/log_reg/p5000_n5000"

print("Running Row-Column Reduction sampling-variance study...")

results_5000_log_reg_cr = run_sampling_variance_row_after_col_log(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_log_reg_cr_p5000_n5000"
)

save_results(
    f"{base}/{results_folder}/results_log_reg_cr_p5000_n5000.pkl",
    results=results_5000_log_reg_cr
)

print("Saved Logistic Regression results.")
# Out:
# Running Row-Column Reduction sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# Computing scores for current seed...
# computing scores for k=10...
# computing scores for k=20...
# computing scores for k=25...
# computing scores for k=50...
# computing scores for k=100...
# computing scores for k=200...
# computing scores for k=300...
# computing scores for k=400...
# computing scores for k=500...
#
# --- Running k = 10 ---
# Setting random seed inside importance-based reduction pipeline for log. regression (seed = 1)...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
#
# --- Running k = 20 ---
# Setting random seed inside importance-based reduction pipeline for log. regression (seed = 1)...
# Performing data reduction...
# Building logistic models...
# Building Full Model / Benchmark...
# Data Reduction & Modeling completed.
#
# --- Running k = 25 ---
# ...

# %% [markdown]
# ### 5.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: Row-Column (p = 10000, n = 10000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p10000_n10000"
results_folder = "Results/log_reg/p10000_n10000"

print("Running Row-Column Reduction sampling-variance study...")

results_10000_log_reg_cr = run_sampling_variance_row_after_col_log(
    k_vector=k_vector,   
    base=base,
    folder=data_folder,
    reps=10,             
    outer_reps=10,       
    test_size=0.2,       
    results_folder = results_folder,
    save_name="results_log_reg_cr_p10000_n10000"
)

save_results(
    f"{base}/{results_folder}/results_log_reg_cr_p10000_n10000.pkl",
    results=results_10000_log_reg_cr
)

print("Saved Logistic Regression results.")

# %% [markdown]
# ## 6. LASSO Analysis

# %% [markdown]
# ### 6.1. Analysis for p = 1.000 and n = 1.000

# %%
#==============================================================================================
# Simulation Study: Row-Reduced Lasso (p = 1000, n = 1000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p1000_n1000"
results_folder = "Results/lasso/p1000_n1000"

print("Running Lasso sampling-variance study...")

results_1000_lasso = run_sampling_variance_lasso_after_row_reduction(
    k_vector=k_vector,
    base=base,
    folder=data_folder,
    reps=10,
    outer_reps=10,
    test_size=0.2,
    results_folder=results_folder,
    save_name="results_lasso_p1000_n1000"
)

save_results(
    f"{base}/{results_folder}/results_lasso_p1000_n1000.pkl",
    results=results_1000_lasso
)

print("Saved Lasso results.")
# Out:
# Running Lasso sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 1
# ...
#
# --- Running k = 10 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 20 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 25 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 50 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 100 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 200 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 300 ---
# Setting the seed...
# ...

# %% [markdown]
# ### 6.2. Analysis for p = 5.000 and n = 5.000

# %%
#==============================================================================================
# Simulation Study: Row-Reduced Lasso (p = 5000, n = 5000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p5000_n5000"
results_folder = "Results/lasso/p5000_n5000"

print("Running Lasso sampling-variance study...")

results_5000_lasso = run_sampling_variance_lasso_after_row_reduction(
    k_vector=k_vector,
    base=base,
    folder=data_folder,
    reps=10,
    outer_reps=10,
    test_size=0.2,
    results_folder=results_folder,
    save_name="results_lasso_p5000_n5000",
    seed_from=9,
    seed_to=10
)

save_results(
    f"{base}/{results_folder}/results_lasso_p5000_n5000.pkl",
    results=results_5000_lasso
)

print("Saved Lasso results.")
# Out:
# Running Lasso sampling-variance study...
# Loading all datasets...
#
# ...
# Running seed = 9
# ...
#
# --- Running k = 10 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 20 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 25 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 50 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 100 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 200 ---
# Setting the seed...
# Performing row reduction...
# Running Lasso (theoretical + binary + CLS)...
# Completed.
#
# --- Running k = 300 ---
# Setting the seed...
# ...

# %% [markdown]
# ### 6.3. Analysis for p = 10.000 and n = 10.000

# %%
#==============================================================================================
# Simulation Study: Row-Reduced Lasso (p = 10000, n = 10000, reps = 10)
#==============================================================================================

data_folder = "Simulation Data/p10000_n10000"
results_folder = "Results/lasso/p10000_n10000"

print("Running Lasso sampling-variance study...")

results_10000_lasso = run_sampling_variance_lasso_after_row_reduction(
    k_vector=k_vector,
    base=base,
    folder=data_folder,
    reps=10,
    outer_reps=10,
    test_size=0.2,
    results_folder=results_folder,
    save_name="results_lasso_p10000_n10000"
)

save_results(
    f"{base}/{results_folder}/results_lasso_p10000_n10000.pkl",
    results=results_10000_lasso
)

print("Saved Lasso results.")

# %% [markdown]
# ### 6.4 Alpha Analysis

# %%
def plot_alpha_vs_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        for rep, a in enumerate(alphas):
            rows.append({"k": k, "Replication": rep+1, "alpha": a})

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k", y="alpha"))
        + geom_boxplot(fill="#4C72B0")
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: α vs. k",
            x="k",
            y="α (Regularization Strength)"
        )
    )

    display(p)
    return df, p


def plot_alpha_distribution(results_lasso, k):
    alphas = results_lasso[k]["alphas"]["Binary"]

    df = pd.DataFrame({"alpha": alphas, "Replication": np.arange(1, len(alphas)+1)})

    p = (
        ggplot(df, aes(x="alpha"))
        + geom_histogram(bins=10, fill="#55A868", color="black")
        + theme_minimal()
        + labs(
            title=f"Distribution of α for k = {k}",
            x="α",
            y="Count"
        )
    )

    display(p)
    return df, p


def compare_alpha_to_theoretical(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        alpha_theory = 1 / np.sqrt(k * np.log(k))

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep+1,
                "alpha_binary": a,
                "alpha_theory": alpha_theory
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="k"))
        + geom_boxplot(aes(y="alpha_binary"), fill="#4C72B0")
        + geom_boxplot(aes(y="alpha_theory"), fill="#DD8452", alpha=0.5)
        + theme_minimal()
        + labs(
            title="Binary-Search α vs. Theoretical α",
            x="k",
            y="α"
        )
    )

    display(p)
    return df, p


def plot_lambda_vs_inverse_k(results_lasso, k_vector):
    rows = []

    for k in k_vector:
        alphas = results_lasso[k]["alphas"]["Binary"]
        inv_k = 1 / k

        for rep, a in enumerate(alphas):
            rows.append({
                "k": k,
                "Replication": rep + 1,
                "alpha": a,
                "inv_k": inv_k
            })

    df = pd.DataFrame(rows)
    df["k"] = df["k"].astype("category")

    p = (
        ggplot(df, aes(x="inv_k", y="alpha"))
        + geom_boxplot(aes(group="k", fill="k"), alpha=0.7)
        + theme_minimal()
        + labs(
            title="Binary-Search Lasso: λ (alpha) vs. 1/k",
            x="1 / k",
            y="λ (Regularization Strength)"
        )
    )

    display(p)
    return df, p

# %%
plot_alpha_vs_k(results_1000_lasso, k_vector)

# %%
plot_alpha_distribution(results_1000_lasso, 25)

# %%
compare_alpha_to_theoretical(results_1000_lasso, k_vector)

# %%
plot_lambda_vs_inverse_k(results_1000_lasso, k_vector)
