# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction - Reduction
#
# Runs all pipelines and saves per-seed pickles.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import warnings

# Suppress sklearn deprecation/convergence warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")
warnings.filterwarnings("ignore", message=".*ConvergenceWarning.*")

# Notebook und Module liegen im selben Verzeichnis (refactored/)
sys.path.append(os.path.dirname(os.path.abspath("__file__")))

from pipeline import (
    run_ols_experiment,
    run_logistic_experiment,
    run_lasso_experiment,
)

# %%
# === Paths ===
BASE = "/Users/timschmale/Documents/GIT/Masterthesis/"
DATA_FOLDER = "Simulation Data/p1000_n1000"
RESULTS_FOLDER = "Results/p1000"

# === Experiment parameters ===
k_vector = [10, 20, 25, 50, 100, 200, 300, 400, 500]
REPS = 10
OUTER_REPS = 10
TEST_SIZE = 0.2
SEED_FROM = 1
SEED_TO = None  # defaults to SEED_FROM + OUTER_REPS

# %% [markdown]
# ## OLS Pipelines

# %%
results_ols_col_row = run_ols_experiment(
    k_vector=k_vector,
    base=BASE,
    data_folder=DATA_FOLDER,
    results_folder=RESULTS_FOLDER,
    reps=REPS,
    outer_reps=OUTER_REPS,
    test_size=TEST_SIZE,
    order="column_first",
    save_name="results_ols_col_row",
    seed_from=SEED_FROM,
    seed_to=SEED_TO,
)
# Out:
# Loading data from Simulation Data/p1000_n1000...
#   Shape: (1000, 1000), 10 replications.
#
# Seed 8...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results_ols_col_row = run_ols_experiment(
#       2     k_vector=k_vector,
#       3     base=BASE,
#       4     data_folder=DATA_FOLDER,
#       5     results_folder=RESULTS_FOLDER,
#       6     reps=REPS,
#       7     outer_reps=OUTER_REPS,
#       8     test_size=TEST_SIZE,
#       9     order="column_first",
#      10     save_name="results_ols_col_row",
#      11     seed_from=8,
#      12     seed_to=11,
#      13 )
#
# File ~/Documents/GIT/Masterthesis/pipeline.py:248, in run_ols_experiment(k_vector, base, data_folder, results_folder, reps, outer_reps, test_size, order, save_name, seed_from, seed_to)
#     246 # Compute scores on TRAINING data for this seed
#     247 print(f"  Computing scores on training data...")
# --> 248 cached_scores, cached_timings = compute_scores_cached(
#     249     X_train_list, y_train_list, k_vector
#     250 )
#     252 seed_results = {}
#     254 for k in k_vector:
#
# File ~/Documents/GIT/Masterthesis/pipeline.py:146, in compute_scores_cached(X_list, y_list, k_vector)
#     143 timings_k = {"LS": [], "CLS": [], "RS": [], "CS": []}
#     145 for i in range(len(X_list)):
# --> 146     s, t = compute_all_scores(X_list[i], y_list[i], k)
#     147     for method in s:
#     148         scores_k[method].append(s[method])
#
# File ~/Documents/GIT/Masterthesis/scoring.py:195, in compute_all_scores(X, y, k, rank_reduce)
#     193 # CLS: Cross-leverage scores (absolute values)
#     194 t0 = time.perf_counter()
# --> 195 scores["CLS"] = get_cross_leverage_scores(X, y, k, rank_reduce=rank_reduce)
#     196 timings["CLS"] = time.perf_counter() - t0
#     198 # RS: Random scores
#
# File ~/Documents/GIT/Masterthesis/scoring.py:85, in get_cross_leverage_scores(X, y, k, rank_reduce)
#      82     X_tilde = X_tilde.T
#      84 if rank_reduce:
# ---> 85     U, _, _ = randomized_svd(X_tilde, n_components=k, random_state=None)
#      86 else:
#      87     U, _, _ = np.linalg.svd(X_tilde, full_matrices=False)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/sklearn/utils/extmath.py:543, in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state, svd_lapack_driver)
#     410 """Compute a truncated randomized SVD.
#     411
#     412 This method solves the fixed-rank approximation problem described in [1]_
#    (...)    540 ((3, 2), (2,), (2, 4))
#     541 """
#     542 M = check_array(M, accept_sparse=True)
# --> 543 return _randomized_svd(
#     544     M,
#     545     n_components=n_components,
#     546     n_oversamples=n_oversamples,
#     547     n_iter=n_iter,
#     548     power_iteration_normalizer=power_iteration_normalizer,
#     549     transpose=transpose,
#     550     flip_sign=flip_sign,
#     551     random_state=random_state,
#     552     svd_lapack_driver=svd_lapack_driver,
#     553 )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/sklearn/utils/extmath.py:593, in _randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state, svd_lapack_driver)
#     589 if transpose:
#     590     # this implementation is a bit faster with smaller shape[1]
#     591     M = M.T
# --> 593 Q = _randomized_range_finder(
#     594     M,
#     595     size=n_random,
#     596     n_iter=n_iter,
#     597     power_iteration_normalizer=power_iteration_normalizer,
#     598     random_state=random_state,
#     599 )
#     601 # project M to the (k + p) dimensional space using the basis vectors
#     602 B = Q.T @ M
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/sklearn/utils/extmath.py:374, in _randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     371 # Perform power iterations with Q to further 'imprint' the top
#     372 # singular vectors of A in Q
#     373 for _ in range(n_iter):
# --> 374     Q, _ = normalizer(A @ Q)
#     375     Q, _ = normalizer(A.T @ Q)
#     377 # Sample the range of A using by linear projection of Q
#     378 # Extract an orthonormal basis
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/.venv/lib/python3.12/site-packages/scipy/linalg/_decomp_lu.py:363, in lu(a, permute_l, overwrite_a, check_finite, p_indices)
#     361     p = np.empty(m, dtype=np.int32)
#     362     u = np.zeros([k, k], dtype=a1.dtype)
# --> 363     lu_dispatcher(a1, u, p, permute_l)
#     364     P, L, U = (p, a1, u) if m > n else (p, u, a1)
#     366 else:  # Stacked array
#     367
#     368     # Prepare the contiguous data holders
#
# KeyboardInterrupt:

# %%
results_ols_col_only = run_ols_experiment(
    k_vector=k_vector,
    base=BASE,
    data_folder=DATA_FOLDER,
    results_folder=RESULTS_FOLDER,
    reps=REPS,
    outer_reps=OUTER_REPS,
    test_size=TEST_SIZE,
    order="column_only",
    save_name="results_ols_col_only",
    seed_from=SEED_FROM,
    seed_to=SEED_TO,
)

# %%
results_ols_row_col = run_ols_experiment(
    k_vector=k_vector,
    base=BASE,
    data_folder=DATA_FOLDER,
    results_folder=RESULTS_FOLDER,
    reps=REPS,
    outer_reps=OUTER_REPS,
    test_size=TEST_SIZE,
    order="row_first",
    save_name="results_ols_row_col",
    seed_from=SEED_FROM,
    seed_to=SEED_TO,
)

# %% [markdown]
# ## Logistic Regression

# %%
results_logistic = run_logistic_experiment(
    k_vector=k_vector,
    base=BASE,
    data_folder=DATA_FOLDER,
    results_folder=RESULTS_FOLDER,
    reps=REPS,
    outer_reps=OUTER_REPS,
    test_size=TEST_SIZE,
    save_name="results_logistic",
    seed_from=SEED_FROM,
    seed_to=SEED_TO,
)
# Out:
# Loading data from Simulation Data/p1000_n1000...
#   Shape: (1000, 1000), 10 replications.
#
# Seed 1...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 1.
#
# Seed 2...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 2.
#
# Seed 3...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 3.
#
# Seed 4...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 4.
#
# Seed 5...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 5.
#
# Seed 6...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 6.
#
# Seed 7...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 7.
#
# Seed 8...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 8.
#
# Seed 9...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 9.
#
# Seed 10...
#   Computing scores on training data...
#   Scores for k=10 done.
#   Scores for k=20 done.
#   Scores for k=25 done.
#   Scores for k=50 done.
#   Scores for k=100 done.
#   Scores for k=200 done.
#   Scores for k=300 done.
#   Scores for k=400 done.
#   Scores for k=500 done.
#   Saved seed 10.

# %% [markdown]
# ## Lasso (3 Variants)

# %%
results_lasso = run_lasso_experiment(
    k_vector=k_vector,
    base=BASE,
    data_folder=DATA_FOLDER,
    results_folder=RESULTS_FOLDER,
    reps=REPS,
    outer_reps=OUTER_REPS,
    test_size=TEST_SIZE,
    save_name="results_lasso",
    seed_from=SEED_FROM,
    seed_to=SEED_TO,
)
