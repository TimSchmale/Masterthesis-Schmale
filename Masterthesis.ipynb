# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction
#
# ## Comparing Reduction Methods for p = 1.000 & n = 1.000

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from column_row_reduction_study import *
from screening_analysis import *

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/Simulation Data")

# %%
#==============================================================================================
# Simulation Study 1: p = 1.000, n = 1.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k50, time_scores_p1000_n1000_k50, C_p1000_n1000_k50, R_p1000_n1000_k50, rmse_p1000_n1000_k50 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 1.000, n = 1.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# set the reps:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k100, time_scores_p1000_n1000_k100, C_p1000_n1000_k100, R_p1000_n1000_k100, rmse_p1000_n1000_k100 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 1.000, n = 1.000, reps = 10, k = 150, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 150

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k150, time_scores_p1000_n1000_k150, C_p1000_n1000_k150, R_p1000_n1000_k150, rmse_p1000_n1000_k150 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  752.0
# r =  4981.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k150, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 1.000, n = 1.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k200, time_scores_p1000_n1000_k200, C_p1000_n1000_k200, R_p1000_n1000_k200, rmse_p1000_n1000_k200 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 5: p = 1.000, n = 1.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n1000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n1000_k300, time_scores_p1000_n1000_k300, C_p1000_n1000_k300, R_p1000_n1000_k300, rmse_p1000_n1000_k300 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 5: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n1000_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 10.000 & n = 10.000

# %%
#==============================================================================================
# Simulation Study 1: p = 10.000, n = 10.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k50, time_scores_p10000_n10000_k50, C_p10000_n10000_k50, R_p10000_n10000_k50, rmse_p10000_n10000_k50 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k100, time_scores_p10000_n10000_k100, C_p10000_n10000_k100, R_p10000_n10000_k100, rmse_p10000_n10000_k100 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k200, time_scores_p10000_n10000_k200, C_p10000_n10000_k200, R_p10000_n10000_k200, rmse_p10000_n10000_k200 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 10.000, n = 10.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k300, time_scores_p10000_n10000_k300, C_p10000_n10000_k300, R_p10000_n10000_k300, rmse_p10000_n10000_k300 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 20.000 & n = 20.000

# %% [markdown]
# ## Comparing Reduction Methods for p = 10.000 & n = 10.000 without Row Reduction

# %%
#==============================================================================================
# Simulation Study 1: p = 10.000, n = 10.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k50rr, time_scores_p10000_n10000_k50rr, C_p10000_n10000_k50rr, R_p10000_n10000_k50rr, rmse_p10000_n10000_k50rr = compare_methods(k, seed, base, folder, reps, row_reduction = False)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k50rr, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k100rr, time_scores_p10000_n10000_k100rr, C_p10000_n10000_k100rr, R_p10000_n10000_k100rr, rmse_p10000_n10000_k100rr = compare_methods(k, seed, base, folder, reps, row_reduction = False)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k100rr, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 10.000, n = 10.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k200rr, time_scores_p10000_n10000_k200rr, C_p10000_n10000_k200rr, R_p10000_n10000_k200rr, rmse_p10000_n10000_k200rr = compare_methods(k, seed, base, folder, reps, row_reduction = False)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k200rr, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 10.000, n = 10.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k300rr, time_scores_p10000_n10000_k300rr, C_p10000_n10000_k300rr, R_p10000_n10000_k300rr, rmse_p10000_n10000_k300rr = compare_methods(k, seed, base, folder, reps, row_reduction = False)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...
# Plotting Time...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k300rr, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 1.000 & n = 1.000 with Row Reduction first
