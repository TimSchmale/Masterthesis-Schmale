# %% [markdown]
# # Regression for Large Matrices with Joint Column and Row Reduction
#
# ## Comparing Reduction Methods for p = 1.000 & n = 900

# %%
#==============================================================================================
# Packages: Import of required packages for the simulation study
#==============================================================================================
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import warnings
from method_comparison import *
from screening_analysis import *

# eliminate warnings for the linear modeling without column names
warnings.filterwarnings(action='ignore', category=UserWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#==============================================================================================
# Setting the base path of the data folders
#==============================================================================================
base = Path("/Users/timschmale/Library/Mobile Documents/com~apple~CloudDocs/Documents/Studium/Data Science/Master/5. Semester/Masterarbeit/Masterthesis/Simulation Data")

# %%
#==============================================================================================
# Simulation Study 1: p = 1.000, n = 900, reps = 10, k = 50, seed = 1
#==============================================================================================

# setting the specific folder:
folder = "p1000_n900"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n900_k50, C_p1000_n900_k50, R_p1000_n900_k50, rmse_p1000_n900_k50 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n900_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 1.000, n = 900, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n900"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# set the reps:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n900_k100, C_p1000_n900_k100, R_p1000_n900_k100, rmse_p1000_n900_k100 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n900_k100, reps)

# %%
#==============================================================================================
# Simulation Study 3: p = 1.000, n = 900, reps = 10, k = 150, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n900"

# set the seed:
seed = 1

# set the rank parameter k:
k = 150

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n900_k150, C_p1000_n900_k150, R_p1000_n900_k150, rmse_p1000_n900_k150 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  752.0
# r =  4981.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n900_k150, reps)

# %%
#==============================================================================================
# Simulation Study 4: p = 1.000, n = 900, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n900"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n900_k200, C_p1000_n900_k200, R_p1000_n900_k200, rmse_p1000_n900_k200 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1060.0
# r =  7384.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n900_k200, reps)

# %%
#==============================================================================================
# Simulation Study 5: p = 1.000, n = 900, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p1000_n900"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# set the reps
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p1000_n900_k300, C_p1000_n900_k300, R_p1000_n900_k300, rmse_p1000_n900_k300 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  1712.0
# r =  12747.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 5: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p1000_n900_k300, reps)

# %% [markdown]
# ## Comparing Reduction Methods for p = 10.000 & n = 10.000

# %%
#==============================================================================================
# Simulation Study 1: p = 10.000, n = 10.000, reps = 10, k = 50, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 50

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k50, C_p10000_n10000_k50, R_p10000_n10000_k50, rmse_p10000_n10000_k50 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  196.0
# r =  1035.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...

# %%
#==============================================================================================
# Simulation Study 1: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k50, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 100, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 100

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k100, C_p10000_n10000_k100, R_p10000_n10000_k100, rmse_p10000_n10000_k100 = compare_methods(k, seed, base, folder, reps)
# Out:
# c =  461.0
# r =  2828.0
# Reading in the simulation data...
# Setting the seed...
# Performing data reduction...
# (8000, 1)
# (2761,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2840,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2681,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3312,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2790,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2502,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3092,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2668,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2650,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3098,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2807,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2914,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2729,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3026,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2672,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2955,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2779,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2817,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2687,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2866,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2720,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2846,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2860,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2801,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2800,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2677,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2930,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2669,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3022,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2362,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2903,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2591,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2872,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2743,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2794,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2966,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2925,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2935,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (2910,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# (8000, 1)
# (3049,)
# <class 'pandas.DataFrame'>
# <class 'list'>
# Visualizing score distributions...
# Building linear models...
# Building Full Model / Benchmark...
# Plotting RMSE...

# %%
#==============================================================================================
# Simulation Study 2: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k100, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 200, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 200

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k200, C_p10000_n10000_k200, R_p10000_n10000_k200, rmse_p10000_n10000_k200 = compare_methods(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 3: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k200, reps)

# %%
#==============================================================================================
# Simulation Study 2: p = 10.000, n = 10.000, reps = 10, k = 300, seed = 1
#==============================================================================================

# set the folder:
folder = "p10000_n10000"

# set the seed:
seed = 1

# set the rank parameter k:
k = 300

# reps setting:
reps = 10

# approximation of reduced dimensions:
c = np.ceil(k * np.log(k))
r = np.ceil(c * np.log(c))

print("c = ", c)
print("r = ", r)

# perform the study:
scores_p10000_n10000_k300, C_p10000_n10000_k300, R_p10000_n10000_k300, rmse_p10000_n10000_k300 = compare_methods(k, seed, base, folder, reps)

# %%
#==============================================================================================
# Simulation Study 4: Evaluation of Screening Performance
#==============================================================================================
evaluate_screening_performance(base, folder, C_p10000_n10000_k300, reps)
